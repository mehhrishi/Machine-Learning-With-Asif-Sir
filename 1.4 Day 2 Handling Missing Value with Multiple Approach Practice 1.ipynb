# %% [markdown]
# ## Type 1
# ### Handling Missing Value with a single Line of code

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#            Name   Python Machine Learning      Age       AI      NLP       Cv
# 0         rishi       90                ?       23       90        ?       23
# 1   rohit_madke  missing               89      NaN  missing       89      NaN
# 2         sahil       78               78        ?       78       78        ?
# 3        rutuja      NaN              NaN  missing      NaN      NaN  missing
# 4       kasturi  missing              NaN       21  missing      NaN       21
# 5        sanjil       65               56       22       65       56       22
# 6       swapnil       45               67        ?       45       67        ?
# 7         rajat       80               45       24       80       45       24
# 8       nishant       70               67  missing       70       67  missing
# 9      ramachal      NaN              NaN       22      NaN      NaN       22
# 10        javed        $          missing       22        ?        ?       80
# 11        yuraj        *                ?       20       80  missing       90
# 12      siddesh      NaN              NaN       23      NaN      NaN       80
# 13      prabhat        ?                /       23       80       78  missing
# 14    rohit_sir        *                /       23  missing        ?      NaN
# 15       shweta        /               80       23       70  missing      NaN
# 16     siddhart      NaN              NaN       23      NaN      NaN       78
# 17       aditya  missing              NaN       22  missing       80       90
# 18    pratiksha      NaN              NaN       21      NaN      NaN       70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            14 non-null     object
#  2   Machine Learning  12 non-null     object
#  3   Age               18 non-null     object
#  4   AI                14 non-null     object
#  5   NLP               13 non-null     object
#  6   Cv                16 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB

# %% [markdown]
#     As you can see the Dataset it has missing values and will try to
#     replace such unwanted values with Nan
#
#     But before replacing it with "Nan" you should always know what are
#     the different unwanted values.

# %%
# As i already know that what are the different unwanted values,
# we have in the dataset so we can mention it while reading the files.
df=pd.read_csv('data2.csv',na_values=['missing','*','?','/','$'])

# %%
df
# Out:
#            Name  Python  Machine Learning   Age    AI   NLP    Cv
# 0         rishi    90.0               NaN  23.0  90.0   NaN  23.0
# 1   rohit_madke     NaN              89.0   NaN   NaN  89.0   NaN
# 2         sahil    78.0              78.0   NaN  78.0  78.0   NaN
# 3        rutuja     NaN               NaN   NaN   NaN   NaN   NaN
# 4       kasturi     NaN               NaN  21.0   NaN   NaN  21.0
# 5        sanjil    65.0              56.0  22.0  65.0  56.0  22.0
# 6       swapnil    45.0              67.0   NaN  45.0  67.0   NaN
# 7         rajat    80.0              45.0  24.0  80.0  45.0  24.0
# 8       nishant    70.0              67.0   NaN  70.0  67.0   NaN
# 9      ramachal     NaN               NaN  22.0   NaN   NaN  22.0
# 10        javed     NaN               NaN  22.0   NaN   NaN  80.0
# 11        yuraj     NaN               NaN  20.0  80.0   NaN  90.0
# 12      siddesh     NaN               NaN  23.0   NaN   NaN  80.0
# 13      prabhat     NaN               NaN  23.0  80.0  78.0   NaN
# 14    rohit_sir     NaN               NaN  23.0   NaN   NaN   NaN
# 15       shweta     NaN              80.0  23.0  70.0   NaN   NaN
# 16     siddhart     NaN               NaN  23.0   NaN   NaN  78.0
# 17       aditya     NaN               NaN  22.0   NaN  80.0  90.0
# 18    pratiksha     NaN               NaN  21.0   NaN   NaN  70.0

# %%
# if you notice something your unwanted values got replaced by Nan
# just try to get the information about our dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            6 non-null      float64
#  2   Machine Learning  7 non-null      float64
#  3   Age               14 non-null     float64
#  4   AI                9 non-null      float64
#  5   NLP               8 non-null      float64
#  6   Cv                11 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.2+ KB

# %%
# See, bydefault it also changed the datatype of those columns,
# which had unwanted values or you can say the missing values.

# %%
df.isnull().sum()
# Out:
# Name                 0
# Python              13
# Machine Learning    12
# Age                  5
# AI                  10
# NLP                 11
# Cv                   8
# dtype: int64

# %%
# df = df.fillna(df.mean(),inplace=True)
# doesnt work

# %%
# lets try to fill the 'Nan'  with Imputation rule
df['Age'].fillna(df.Age.mean(),inplace=True)
df['Python'].fillna(round(df.Python.mean(),2),inplace=True)
df['Machine Learning'].fillna(round(df['Machine Learning'].mean(),2),inplace=True)
df['AI'].fillna(round(df.AI.mean(),2),inplace=True)
df['NLP'].fillna(round(df['NLP'].mean(),2),inplace=True)
df['Cv'].fillna(round(df['Cv'].mean(),2),inplace=True)

# %%
df.head()
# Out:
#           Name  Python  Machine Learning        Age     AI   NLP     Cv
# 0        rishi   90.00             68.86  23.000000  90.00  70.0  23.00
# 1  rohit_madke   71.33             89.00  22.285714  73.11  89.0  54.55
# 2        sahil   78.00             78.00  22.285714  78.00  78.0  54.55
# 3       rutuja   71.33             68.86  22.285714  73.11  70.0  54.55
# 4      kasturi   71.33             68.86  21.000000  73.11  70.0  21.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            19 non-null     float64
#  2   Machine Learning  19 non-null     float64
#  3   Age               19 non-null     float64
#  4   AI                19 non-null     float64
#  5   NLP               19 non-null     float64
#  6   Cv                19 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.2+ KB

# %%
# let change the datatype of the Age column from float to int
# because Age in float doesn't seems to be relevant ib the Dataset
# do change the Age datatype from float to int
df['Age'] = df['Age'].astype('int')

# %%
df['Age'].dtype
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            19 non-null     float64
#  2   Machine Learning  19 non-null     float64
#  3   Age               19 non-null     int32
#  4   AI                19 non-null     float64
#  5   NLP               19 non-null     float64
#  6   Cv                19 non-null     float64
# dtypes: float64(5), int32(1), object(1)
# memory usage: 1.1+ KB

# %%
# if you want to change the datatype of Multiple column 
# lets change the datatype of "nlp" and "cv" from float to int
df = df.astype({
    "NLP":"int",
    "Cv":'int'
})

# %%
print(df['NLP'].dtype)
print(df['Cv'].dtype)
# Out:
# int32
# int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            19 non-null     float64
#  2   Machine Learning  19 non-null     float64
#  3   Age               19 non-null     int32
#  4   AI                19 non-null     float64
#  5   NLP               19 non-null     int32
#  6   Cv                19 non-null     int32
# dtypes: float64(3), int32(3), object(1)
# memory usage: 964.0+ bytes

# %% [markdown]
# ## Type 2
# ### Handling Missing Value with Regex

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#            Name   Python Machine Learning      Age       AI      NLP       Cv
# 0         rishi       90                ?       23       90        ?       23
# 1   rohit_madke  missing               89      NaN  missing       89      NaN
# 2         sahil       78               78        ?       78       78        ?
# 3        rutuja      NaN              NaN  missing      NaN      NaN  missing
# 4       kasturi  missing              NaN       21  missing      NaN       21
# 5        sanjil       65               56       22       65       56       22
# 6       swapnil       45               67        ?       45       67        ?
# 7         rajat       80               45       24       80       45       24
# 8       nishant       70               67  missing       70       67  missing
# 9      ramachal      NaN              NaN       22      NaN      NaN       22
# 10        javed        $          missing       22        ?        ?       80
# 11        yuraj        *                ?       20       80  missing       90
# 12      siddesh      NaN              NaN       23      NaN      NaN       80
# 13      prabhat        ?                /       23       80       78  missing
# 14    rohit_sir        *                /       23  missing        ?      NaN
# 15       shweta        /               80       23       70  missing      NaN
# 16     siddhart      NaN              NaN       23      NaN      NaN       78
# 17       aditya  missing              NaN       22  missing       80       90
# 18    pratiksha      NaN              NaN       21      NaN      NaN       70

# %%
# Import Regular expression 
import re

# %%
# Now lets replace unwanted value with "Nan" using regex
import re
df.replace({
    'Python':'\D',
    'Machine Learning':'\D',
    'Age':'\D',
    'AI':'\D',
    'NLP':'\D',
    'Cv':'\D'
    
},np.nan,regex=True,inplace=True)

# %%
df
# Out:
#            Name Python Machine Learning  Age   AI  NLP   Cv
# 0         rishi     90              NaN   23   90  NaN   23
# 1   rohit_madke    NaN               89  NaN  NaN   89  NaN
# 2         sahil     78               78  NaN   78   78  NaN
# 3        rutuja    NaN              NaN  NaN  NaN  NaN  NaN
# 4       kasturi    NaN              NaN   21  NaN  NaN   21
# 5        sanjil     65               56   22   65   56   22
# 6       swapnil     45               67  NaN   45   67  NaN
# 7         rajat     80               45   24   80   45   24
# 8       nishant     70               67  NaN   70   67  NaN
# 9      ramachal    NaN              NaN   22  NaN  NaN   22
# 10        javed    NaN              NaN   22  NaN  NaN   80
# 11        yuraj    NaN              NaN   20   80  NaN   90
# 12      siddesh    NaN              NaN   23  NaN  NaN   80
# 13      prabhat    NaN              NaN   23   80   78  NaN
# 14    rohit_sir    NaN              NaN   23  NaN  NaN  NaN
# 15       shweta    NaN               80   23   70  NaN  NaN
# 16     siddhart    NaN              NaN   23  NaN  NaN   78
# 17       aditya    NaN              NaN   22  NaN   80   90
# 18    pratiksha    NaN              NaN   21  NaN  NaN   70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            6 non-null      object
#  2   Machine Learning  7 non-null      object
#  3   Age               14 non-null     object
#  4   AI                9 non-null      object
#  5   NLP               8 non-null      object
#  6   Cv                11 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB

# %%
df.columns
# Out:
# Index(['Name', 'Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv'], dtype='object')

# %%
list1 = list(df.columns)

# %%
list1
# Out:
# ['Name', 'Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv']

# %%
list1 = list1[1:]

# %%
list1
# Out:
# ['Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv']

# %%
# let change the Datatype of the above mention list

# %%
for i in list1:
    df[i] = df[i].astype("float")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            6 non-null      float64
#  2   Machine Learning  7 non-null      float64
#  3   Age               14 non-null     float64
#  4   AI                9 non-null      float64
#  5   NLP               8 non-null      float64
#  6   Cv                11 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.2+ KB

# %%
# Let replace the Nan with imputation usnig for loop:
for i in list1:
    df[i].fillna(round(df[i].mean(),2),inplace=True)
df

# alternate way

# for i in list1:
#     mean = df[i].mean()
#     df[i].fillna(mean,inplace=True)
# df
# Out:
#            Name  Python  Machine Learning    Age     AI   NLP     Cv
# 0         rishi   90.00             68.86  23.00  90.00  70.0  23.00
# 1   rohit_madke   71.33             89.00  22.29  73.11  89.0  54.55
# 2         sahil   78.00             78.00  22.29  78.00  78.0  54.55
# 3        rutuja   71.33             68.86  22.29  73.11  70.0  54.55
# 4       kasturi   71.33             68.86  21.00  73.11  70.0  21.00
# 5        sanjil   65.00             56.00  22.00  65.00  56.0  22.00
# 6       swapnil   45.00             67.00  22.29  45.00  67.0  54.55
# 7         rajat   80.00             45.00  24.00  80.00  45.0  24.00
# 8       nishant   70.00             67.00  22.29  70.00  67.0  54.55
# 9      ramachal   71.33             68.86  22.00  73.11  70.0  22.00
# 10        javed   71.33             68.86  22.00  73.11  70.0  80.00
# 11        yuraj   71.33             68.86  20.00  80.00  70.0  90.00
# 12      siddesh   71.33             68.86  23.00  73.11  70.0  80.00
# 13      prabhat   71.33             68.86  23.00  80.00  78.0  54.55
# 14    rohit_sir   71.33             68.86  23.00  73.11  70.0  54.55
# 15       shweta   71.33             80.00  23.00  70.00  70.0  54.55
# 16     siddhart   71.33             68.86  23.00  73.11  70.0  78.00
# 17       aditya   71.33             68.86  22.00  73.11  80.0  90.00
# 18    pratiksha   71.33             68.86  21.00  73.11  70.0  70.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            6 non-null      float64
#  2   Machine Learning  7 non-null      float64
#  3   Age               14 non-null     float64
#  4   AI                9 non-null      float64
#  5   NLP               8 non-null      float64
#  6   Cv                11 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.2+ KB

# %%
df
# Out:
#            Name  Python  Machine Learning    Age     AI   NLP     Cv
# 0         rishi   90.00             68.86  23.00  90.00  70.0  23.00
# 1   rohit_madke   71.33             89.00  22.29  73.11  89.0  54.55
# 2         sahil   78.00             78.00  22.29  78.00  78.0  54.55
# 3        rutuja   71.33             68.86  22.29  73.11  70.0  54.55
# 4       kasturi   71.33             68.86  21.00  73.11  70.0  21.00
# 5        sanjil   65.00             56.00  22.00  65.00  56.0  22.00
# 6       swapnil   45.00             67.00  22.29  45.00  67.0  54.55
# 7         rajat   80.00             45.00  24.00  80.00  45.0  24.00
# 8       nishant   70.00             67.00  22.29  70.00  67.0  54.55
# 9      ramachal   71.33             68.86  22.00  73.11  70.0  22.00
# 10        javed   71.33             68.86  22.00  73.11  70.0  80.00
# 11        yuraj   71.33             68.86  20.00  80.00  70.0  90.00
# 12      siddesh   71.33             68.86  23.00  73.11  70.0  80.00
# 13      prabhat   71.33             68.86  23.00  80.00  78.0  54.55
# 14    rohit_sir   71.33             68.86  23.00  73.11  70.0  54.55
# 15       shweta   71.33             80.00  23.00  70.00  70.0  54.55
# 16     siddhart   71.33             68.86  23.00  73.11  70.0  78.00
# 17       aditya   71.33             68.86  22.00  73.11  80.0  90.00
# 18    pratiksha   71.33             68.86  21.00  73.11  70.0  70.00

# %%
# checking for the Null Values
df.isnull().sum()
# Out:
# Name                0
# Python              0
# Machine Learning    0
# Age                 0
# AI                  0
# NLP                 0
# Cv                  0
# dtype: int64

# %% [markdown]
# ### Type 3
# #### Handling Missing Value with na_value parameter using regex in that

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import re

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#            Name   Python Machine Learning      Age       AI      NLP       Cv
# 0         rishi       90                ?       23       90        ?       23
# 1   rohit_madke  missing               89      NaN  missing       89      NaN
# 2         sahil       78               78        ?       78       78        ?
# 3        rutuja      NaN              NaN  missing      NaN      NaN  missing
# 4       kasturi  missing              NaN       21  missing      NaN       21
# 5        sanjil       65               56       22       65       56       22
# 6       swapnil       45               67        ?       45       67        ?
# 7         rajat       80               45       24       80       45       24
# 8       nishant       70               67  missing       70       67  missing
# 9      ramachal      NaN              NaN       22      NaN      NaN       22
# 10        javed        $          missing       22        ?        ?       80
# 11        yuraj        *                ?       20       80  missing       90
# 12      siddesh      NaN              NaN       23      NaN      NaN       80
# 13      prabhat        ?                /       23       80       78  missing
# 14    rohit_sir        *                /       23  missing        ?      NaN
# 15       shweta        /               80       23       70  missing      NaN
# 16     siddhart      NaN              NaN       23      NaN      NaN       78
# 17       aditya  missing              NaN       22  missing       80       90
# 18    pratiksha      NaN              NaN       21      NaN      NaN       70

# %%
df = pd.read_csv('data2.csv',na_values=({
    'Python':'\D',
    'Machine Learning':'\D',
    'Age':'\D',
    'AI':'\D',
    'NLP':'\D',
    'Cv':'\D'
    
},np.nan,regex=True)
# Out:
#   Cell In [148], line 9
#     },np.nan,regex=True)
#                   ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#            Name   Python Machine Learning      Age       AI      NLP       Cv
# 0         rishi       90                ?       23       90        ?       23
# 1   rohit_madke  missing               89      NaN  missing       89      NaN
# 2         sahil       78               78        ?       78       78        ?
# 3        rutuja      NaN              NaN  missing      NaN      NaN  missing
# 4       kasturi  missing              NaN       21  missing      NaN       21
# 5        sanjil       65               56       22       65       56       22
# 6       swapnil       45               67        ?       45       67        ?
# 7         rajat       80               45       24       80       45       24
# 8       nishant       70               67  missing       70       67  missing
# 9      ramachal      NaN              NaN       22      NaN      NaN       22
# 10        javed        $          missing       22        ?        ?       80
# 11        yuraj        *                ?       20       80  missing       90
# 12      siddesh      NaN              NaN       23      NaN      NaN       80
# 13      prabhat        ?                /       23       80       78  missing
# 14    rohit_sir        *                /       23  missing        ?      NaN
# 15       shweta        /               80       23       70  missing      NaN
# 16     siddhart      NaN              NaN       23      NaN      NaN       78
# 17       aditya  missing              NaN       22  missing       80       90
# 18    pratiksha      NaN              NaN       21      NaN      NaN       70

# %%
# it doesnt seems to be working in that way which i was expecting.

# %% [markdown]
# ## Type 4
# ### Handle Missing Value using replace function

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#            Name   Python Machine Learning      Age       AI      NLP       Cv
# 0         rishi       90                ?       23       90        ?       23
# 1   rohit_madke  missing               89      NaN  missing       89      NaN
# 2         sahil       78               78        ?       78       78        ?
# 3        rutuja      NaN              NaN  missing      NaN      NaN  missing
# 4       kasturi  missing              NaN       21  missing      NaN       21
# 5        sanjil       65               56       22       65       56       22
# 6       swapnil       45               67        ?       45       67        ?
# 7         rajat       80               45       24       80       45       24
# 8       nishant       70               67  missing       70       67  missing
# 9      ramachal      NaN              NaN       22      NaN      NaN       22
# 10        javed        $          missing       22        ?        ?       80
# 11        yuraj        *                ?       20       80  missing       90
# 12      siddesh      NaN              NaN       23      NaN      NaN       80
# 13      prabhat        ?                /       23       80       78  missing
# 14    rohit_sir        *                /       23  missing        ?      NaN
# 15       shweta        /               80       23       70  missing      NaN
# 16     siddhart      NaN              NaN       23      NaN      NaN       78
# 17       aditya  missing              NaN       22  missing       80       90
# 18    pratiksha      NaN              NaN       21      NaN      NaN       70

# %%
df.replace(['missing','*','?','/','$'],np.nan,inplace=True)

# %%
df
# Out:
#            Name Python Machine Learning  Age   AI  NLP   Cv
# 0         rishi     90              NaN   23   90  NaN   23
# 1   rohit_madke    NaN               89  NaN  NaN   89  NaN
# 2         sahil     78               78  NaN   78   78  NaN
# 3        rutuja    NaN              NaN  NaN  NaN  NaN  NaN
# 4       kasturi    NaN              NaN   21  NaN  NaN   21
# 5        sanjil     65               56   22   65   56   22
# 6       swapnil     45               67  NaN   45   67  NaN
# 7         rajat     80               45   24   80   45   24
# 8       nishant     70               67  NaN   70   67  NaN
# 9      ramachal    NaN              NaN   22  NaN  NaN   22
# 10        javed    NaN              NaN   22  NaN  NaN   80
# 11        yuraj    NaN              NaN   20   80  NaN   90
# 12      siddesh    NaN              NaN   23  NaN  NaN   80
# 13      prabhat    NaN              NaN   23   80   78  NaN
# 14    rohit_sir    NaN              NaN   23  NaN  NaN  NaN
# 15       shweta    NaN               80   23   70  NaN  NaN
# 16     siddhart    NaN              NaN   23  NaN  NaN   78
# 17       aditya    NaN              NaN   22  NaN   80   90
# 18    pratiksha    NaN              NaN   21  NaN  NaN   70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            6 non-null      object
#  2   Machine Learning  7 non-null      object
#  3   Age               14 non-null     object
#  4   AI                9 non-null      object
#  5   NLP               8 non-null      object
#  6   Cv                11 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB

# %%
df.columns
# Out:
# Index(['Name', 'Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv'], dtype='object')

# %%
list1 = list(df.columns)

# %%
list1
# Out:
# ['Name', 'Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv']

# %%
list1 = list1[1:]

# %%
list1
# Out:
# ['Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv']

# %%
# lets change the Datatype with using for loop which we saw earlier
for i in list1:
    df[i] = df[i].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            6 non-null      float64
#  2   Machine Learning  7 non-null      float64
#  3   Age               14 non-null     float64
#  4   AI                9 non-null      float64
#  5   NLP               8 non-null      float64
#  6   Cv                11 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.2+ KB

# %%
df.isnull().sum()
# Out:
# Name                 0
# Python              13
# Machine Learning    12
# Age                  5
# AI                  10
# NLP                 11
# Cv                   8
# dtype: int64

# %%
df
# Out:
#            Name  Python  Machine Learning   Age    AI   NLP    Cv
# 0         rishi    90.0               NaN  23.0  90.0   NaN  23.0
# 1   rohit_madke     NaN              89.0   NaN   NaN  89.0   NaN
# 2         sahil    78.0              78.0   NaN  78.0  78.0   NaN
# 3        rutuja     NaN               NaN   NaN   NaN   NaN   NaN
# 4       kasturi     NaN               NaN  21.0   NaN   NaN  21.0
# 5        sanjil    65.0              56.0  22.0  65.0  56.0  22.0
# 6       swapnil    45.0              67.0   NaN  45.0  67.0   NaN
# 7         rajat    80.0              45.0  24.0  80.0  45.0  24.0
# 8       nishant    70.0              67.0   NaN  70.0  67.0   NaN
# 9      ramachal     NaN               NaN  22.0   NaN   NaN  22.0
# 10        javed     NaN               NaN  22.0   NaN   NaN  80.0
# 11        yuraj     NaN               NaN  20.0  80.0   NaN  90.0
# 12      siddesh     NaN               NaN  23.0   NaN   NaN  80.0
# 13      prabhat     NaN               NaN  23.0  80.0  78.0   NaN
# 14    rohit_sir     NaN               NaN  23.0   NaN   NaN   NaN
# 15       shweta     NaN              80.0  23.0  70.0   NaN   NaN
# 16     siddhart     NaN               NaN  23.0   NaN   NaN  78.0
# 17       aditya     NaN               NaN  22.0   NaN  80.0  90.0
# 18    pratiksha     NaN               NaN  21.0   NaN   NaN  70.0

# %%
# Now lets replace "Nan" with the imputation rule 
for i in list1:
    df[i].fillna(round(df[i].mean(),2),inplace=True)
df
# Out:
#            Name  Python  Machine Learning    Age     AI   NLP     Cv
# 0         rishi   90.00             68.86  23.00  90.00  70.0  23.00
# 1   rohit_madke   71.33             89.00  22.29  73.11  89.0  54.55
# 2         sahil   78.00             78.00  22.29  78.00  78.0  54.55
# 3        rutuja   71.33             68.86  22.29  73.11  70.0  54.55
# 4       kasturi   71.33             68.86  21.00  73.11  70.0  21.00
# 5        sanjil   65.00             56.00  22.00  65.00  56.0  22.00
# 6       swapnil   45.00             67.00  22.29  45.00  67.0  54.55
# 7         rajat   80.00             45.00  24.00  80.00  45.0  24.00
# 8       nishant   70.00             67.00  22.29  70.00  67.0  54.55
# 9      ramachal   71.33             68.86  22.00  73.11  70.0  22.00
# 10        javed   71.33             68.86  22.00  73.11  70.0  80.00
# 11        yuraj   71.33             68.86  20.00  80.00  70.0  90.00
# 12      siddesh   71.33             68.86  23.00  73.11  70.0  80.00
# 13      prabhat   71.33             68.86  23.00  80.00  78.0  54.55
# 14    rohit_sir   71.33             68.86  23.00  73.11  70.0  54.55
# 15       shweta   71.33             80.00  23.00  70.00  70.0  54.55
# 16     siddhart   71.33             68.86  23.00  73.11  70.0  78.00
# 17       aditya   71.33             68.86  22.00  73.11  80.0  90.00
# 18    pratiksha   71.33             68.86  21.00  73.11  70.0  70.00

# %% [markdown]
# # Type 5
# ### Handling Missing Value with a If-else Statement

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#            Name   Python Machine Learning      Age       AI      NLP       Cv
# 0         rishi       90                ?       23       90        ?       23
# 1   rohit_madke  missing               89      NaN  missing       89      NaN
# 2         sahil       78               78        ?       78       78        ?
# 3        rutuja      NaN              NaN  missing      NaN      NaN  missing
# 4       kasturi  missing              NaN       21  missing      NaN       21
# 5        sanjil       65               56       22       65       56       22
# 6       swapnil       45               67        ?       45       67        ?
# 7         rajat       80               45       24       80       45       24
# 8       nishant       70               67  missing       70       67  missing
# 9      ramachal      NaN              NaN       22      NaN      NaN       22
# 10        javed        $          missing       22        ?        ?       80
# 11        yuraj        *                ?       20       80  missing       90
# 12      siddesh      NaN              NaN       23      NaN      NaN       80
# 13      prabhat        ?                /       23       80       78  missing
# 14    rohit_sir        *                /       23  missing        ?      NaN
# 15       shweta        /               80       23       70  missing      NaN
# 16     siddhart      NaN              NaN       23      NaN      NaN       78
# 17       aditya  missing              NaN       22  missing       80       90
# 18    pratiksha      NaN              NaN       21      NaN      NaN       70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            14 non-null     object
#  2   Machine Learning  12 non-null     object
#  3   Age               18 non-null     object
#  4   AI                14 non-null     object
#  5   NLP               13 non-null     object
#  6   Cv                16 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB

# %%
df['Python'].value_counts()
# Out:
# missing    3
# *          2
# 90         1
# 78         1
# 65         1
# 45         1
# 80         1
# 70         1
# $          1
# ?          1
# /          1
# Name: Python, dtype: int64

# %%
def pynan(x):
    if x in ['*','$','?','/','missing']:
        x = np.nan
        return x
    else:
        return x

# %%
df['Python'] = df['Python'].map(pynan)

# %%
df['Python']
# Out:
# 0      90
# 1     NaN
# 2      78
# 3     NaN
# 4     NaN
# 5      65
# 6      45
# 7      80
# 8      70
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# Name: Python, dtype: object

# %%
df['Machine Learning'].value_counts()
# Out:
# ?          2
# 67         2
# /          2
# 89         1
# 78         1
# 56         1
# 45         1
# missing    1
# 80         1
# Name: Machine Learning, dtype: int64

# %%
df['Machine Learning'].dtype
# Out:
# dtype('O')

# %%
def mlnan(x):
    if x in ['?','/','missing']:
        x = np.nan
        return x
    else:
        return x

# %%
df['Machine Learning'] = df['Machine Learning'].map(mlnan)

# %%
df['Machine Learning']
# Out:
# 0     NaN
# 1      89
# 2      78
# 3     NaN
# 4     NaN
# 5      56
# 6      67
# 7      45
# 8      67
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15     80
# 16    NaN
# 17    NaN
# 18    NaN
# Name: Machine Learning, dtype: object

# %%
df['Machine Learning'].isnull().sum()
# Out:
# 12

# %%
df['Age'].value_counts()
# Out:
# 23         6
# 22         4
# ?          2
# missing    2
# 21         2
# 24         1
# 20         1
# Name: Age, dtype: int64

# %%
def agenan(x):
    if x in ['?','missing']:
        x = np.nan
        return x
    else:
        return x

# %%
df['Age'] = df['Age'].map(agenan)

# %%
df['Age']
# Out:
# 0      23
# 1     NaN
# 2     NaN
# 3     NaN
# 4      21
# 5      22
# 6     NaN
# 7      24
# 8     NaN
# 9      22
# 10     22
# 11     20
# 12     23
# 13     23
# 14     23
# 15     23
# 16     23
# 17     22
# 18     21
# Name: Age, dtype: object

# %%
df['AI'].value_counts()
# Out:
# missing    4
# 80         3
# 70         2
# 90         1
# 78         1
# 65         1
# 45         1
# ?          1
# Name: AI, dtype: int64

# %%
def ainan(x):
    if x in ['missing','?']:
        x = np.nan
        return x
    else:
        return x

# %%
df['AI'] = df['AI'].map(ainan)

# %%
df['AI']
# Out:
# 0      90
# 1     NaN
# 2      78
# 3     NaN
# 4     NaN
# 5      65
# 6      45
# 7      80
# 8      70
# 9     NaN
# 10    NaN
# 11     80
# 12    NaN
# 13     80
# 14    NaN
# 15     70
# 16    NaN
# 17    NaN
# 18    NaN
# Name: AI, dtype: object

# %%
df['NLP'].value_counts()
# Out:
# ?          3
# 78         2
# 67         2
# missing    2
# 89         1
# 56         1
# 45         1
# 80         1
# Name: NLP, dtype: int64

# %%
def nlpnan(x):
    if x in ['?','missing']:
        x = np.nan
        return x
    else:
        return x

# %%
df['NLP'] = df['NLP'].map(nlpnan)

# %%
df['NLP']
# Out:
# 0     NaN
# 1      89
# 2      78
# 3     NaN
# 4     NaN
# 5      56
# 6      67
# 7      45
# 8      67
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13     78
# 14    NaN
# 15    NaN
# 16    NaN
# 17     80
# 18    NaN
# Name: NLP, dtype: object

# %%
df['Cv'].value_counts()
# Out:
# missing    3
# ?          2
# 22         2
# 80         2
# 90         2
# 23         1
# 21         1
# 24         1
# 78         1
# 70         1
# Name: Cv, dtype: int64

# %%
def cvnan(x):
    if x in ['missing','?']:
        x = np.nan
        return x
    else:
        return x

# %%
df['Cv'] = df['Cv'].map(cvnan)

# %%
df['Cv']
# Out:
# 0      23
# 1     NaN
# 2     NaN
# 3     NaN
# 4      21
# 5      22
# 6     NaN
# 7      24
# 8     NaN
# 9      22
# 10     80
# 11     90
# 12     80
# 13    NaN
# 14    NaN
# 15    NaN
# 16     78
# 17     90
# 18     70
# Name: Cv, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            6 non-null      object
#  2   Machine Learning  7 non-null      object
#  3   Age               14 non-null     object
#  4   AI                9 non-null      object
#  5   NLP               8 non-null      object
#  6   Cv                11 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB

# %%
# Changing the Datatype

# %%
df['Python'] = df['Python'].astype('float')

# %%
df.Python.dtype
# Out:
# dtype('float64')

# %%
df['Machine Learning'] = df['Machine Learning'].astype('float')

# %%
df['Machine Learning'].dtype
# Out:
# dtype('float64')

# %%
df['Age'] = df['Age'].astype('float')

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %%
df['AI']=df['AI'].astype("float")

# %%
df['AI'].dtype
# Out:
# dtype('float64')

# %%
df['NLP'] = df['NLP'].astype('float')

# %%
df['NLP'].dtype
# Out:
# dtype('float64')

# %%
df['Cv'] = df['Cv'].astype('float')

# %%
df['Cv'].dtype
# Out:
# dtype('float64')

# %%
# Replacing the Nan values with iomputation rule

# %%
df['Python'].fillna(round(df.Python.mean(),2),inplace=True)

# %%
df['Python']
# Out:
# 0     90.00
# 1     71.33
# 2     78.00
# 3     71.33
# 4     71.33
# 5     65.00
# 6     45.00
# 7     80.00
# 8     70.00
# 9     71.33
# 10    71.33
# 11    71.33
# 12    71.33
# 13    71.33
# 14    71.33
# 15    71.33
# 16    71.33
# 17    71.33
# 18    71.33
# Name: Python, dtype: float64

# %%
df
# Out:
#            Name  Python  Machine Learning   Age    AI   NLP    Cv
# 0         rishi   90.00               NaN  23.0  90.0   NaN  23.0
# 1   rohit_madke   71.33              89.0   NaN   NaN  89.0   NaN
# 2         sahil   78.00              78.0   NaN  78.0  78.0   NaN
# 3        rutuja   71.33               NaN   NaN   NaN   NaN   NaN
# 4       kasturi   71.33               NaN  21.0   NaN   NaN  21.0
# 5        sanjil   65.00              56.0  22.0  65.0  56.0  22.0
# 6       swapnil   45.00              67.0   NaN  45.0  67.0   NaN
# 7         rajat   80.00              45.0  24.0  80.0  45.0  24.0
# 8       nishant   70.00              67.0   NaN  70.0  67.0   NaN
# 9      ramachal   71.33               NaN  22.0   NaN   NaN  22.0
# 10        javed   71.33               NaN  22.0   NaN   NaN  80.0
# 11        yuraj   71.33               NaN  20.0  80.0   NaN  90.0
# 12      siddesh   71.33               NaN  23.0   NaN   NaN  80.0
# 13      prabhat   71.33               NaN  23.0  80.0  78.0   NaN
# 14    rohit_sir   71.33               NaN  23.0   NaN   NaN   NaN
# 15       shweta   71.33              80.0  23.0  70.0   NaN   NaN
# 16     siddhart   71.33               NaN  23.0   NaN   NaN  78.0
# 17       aditya   71.33               NaN  22.0   NaN  80.0  90.0
# 18    pratiksha   71.33               NaN  21.0   NaN   NaN  70.0

# %%
df['Machine Learning'].fillna(round(df['Machine Learning'].mean(),2),inplace=True)

# %%
df['Machine Learning']
# Out:
# 0     68.86
# 1     89.00
# 2     78.00
# 3     68.86
# 4     68.86
# 5     56.00
# 6     67.00
# 7     45.00
# 8     67.00
# 9     68.86
# 10    68.86
# 11    68.86
# 12    68.86
# 13    68.86
# 14    68.86
# 15    80.00
# 16    68.86
# 17    68.86
# 18    68.86
# Name: Machine Learning, dtype: float64

# %%
df['Age'].fillna(round(df['Age'].mean(),0),inplace=True)

# %%
df['Age'] = df['Age'].astype('int')

# %%
df['Age']
# Out:
# 0     23
# 1     22
# 2     22
# 3     22
# 4     21
# 5     22
# 6     22
# 7     24
# 8     22
# 9     22
# 10    22
# 11    20
# 12    23
# 13    23
# 14    23
# 15    23
# 16    23
# 17    22
# 18    21
# Name: Age, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            19 non-null     float64
#  2   Machine Learning  19 non-null     float64
#  3   Age               19 non-null     int32
#  4   AI                9 non-null      float64
#  5   NLP               8 non-null      float64
#  6   Cv                11 non-null     float64
# dtypes: float64(5), int32(1), object(1)
# memory usage: 1.1+ KB

# %%
df['AI'].fillna(df['AI'].mean(),inplace=True)

# %%
df['AI'] = round(df['AI'],2)

# %%
df['AI']
# Out:
# 0     90.00
# 1     73.11
# 2     78.00
# 3     73.11
# 4     73.11
# 5     65.00
# 6     45.00
# 7     80.00
# 8     70.00
# 9     73.11
# 10    73.11
# 11    80.00
# 12    73.11
# 13    80.00
# 14    73.11
# 15    70.00
# 16    73.11
# 17    73.11
# 18    73.11
# Name: AI, dtype: float64

# %%
df['NLP'].fillna(round(df['NLP'].mean(),2),inplace=True)

# %%
df['NLP']
# Out:
# 0     70.0
# 1     89.0
# 2     78.0
# 3     70.0
# 4     70.0
# 5     56.0
# 6     67.0
# 7     45.0
# 8     67.0
# 9     70.0
# 10    70.0
# 11    70.0
# 12    70.0
# 13    78.0
# 14    70.0
# 15    70.0
# 16    70.0
# 17    80.0
# 18    70.0
# Name: NLP, dtype: float64

# %%
df['Cv'].fillna(round(df['Cv'].mean(),2),inplace=True)

# %%
df['Cv']
# Out:
# 0     23.00
# 1     54.55
# 2     54.55
# 3     54.55
# 4     21.00
# 5     22.00
# 6     54.55
# 7     24.00
# 8     54.55
# 9     22.00
# 10    80.00
# 11    90.00
# 12    80.00
# 13    54.55
# 14    54.55
# 15    54.55
# 16    78.00
# 17    90.00
# 18    70.00
# Name: Cv, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            19 non-null     float64
#  2   Machine Learning  19 non-null     float64
#  3   Age               19 non-null     int32
#  4   AI                19 non-null     float64
#  5   NLP               19 non-null     float64
#  6   Cv                19 non-null     float64
# dtypes: float64(5), int32(1), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# ### Type
# ## pd.to_numeric

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data2.csv')
df
# Out:
#            Name   Python Machine Learning      Age       AI      NLP       Cv
# 0         rishi       90                ?       23       90        ?       23
# 1   rohit_madke  missing               89      NaN  missing       89      NaN
# 2         sahil       78               78        ?       78       78        ?
# 3        rutuja      NaN              NaN  missing      NaN      NaN  missing
# 4       kasturi  missing              NaN       21  missing      NaN       21
# 5        sanjil       65               56       22       65       56       22
# 6       swapnil       45               67        ?       45       67        ?
# 7         rajat       80               45       24       80       45       24
# 8       nishant       70               67  missing       70       67  missing
# 9      ramachal      NaN              NaN       22      NaN      NaN       22
# 10        javed        $          missing       22        ?        ?       80
# 11        yuraj        *                ?       20       80  missing       90
# 12      siddesh      NaN              NaN       23      NaN      NaN       80
# 13      prabhat        ?                /       23       80       78  missing
# 14    rohit_sir        *                /       23  missing        ?      NaN
# 15       shweta        /               80       23       70  missing      NaN
# 16     siddhart      NaN              NaN       23      NaN      NaN       78
# 17       aditya  missing              NaN       22  missing       80       90
# 18    pratiksha      NaN              NaN       21      NaN      NaN       70

# %%
df['Python']=pd.to_numeric(df.Python,errors='coerce')

# %%
df
# Out:
#            Name  Python Machine Learning      Age       AI      NLP       Cv
# 0         rishi    90.0                ?       23       90        ?       23
# 1   rohit_madke     NaN               89      NaN  missing       89      NaN
# 2         sahil    78.0               78        ?       78       78        ?
# 3        rutuja     NaN              NaN  missing      NaN      NaN  missing
# 4       kasturi     NaN              NaN       21  missing      NaN       21
# 5        sanjil    65.0               56       22       65       56       22
# 6       swapnil    45.0               67        ?       45       67        ?
# 7         rajat    80.0               45       24       80       45       24
# 8       nishant    70.0               67  missing       70       67  missing
# 9      ramachal     NaN              NaN       22      NaN      NaN       22
# 10        javed     NaN          missing       22        ?        ?       80
# 11        yuraj     NaN                ?       20       80  missing       90
# 12      siddesh     NaN              NaN       23      NaN      NaN       80
# 13      prabhat     NaN                /       23       80       78  missing
# 14    rohit_sir     NaN                /       23  missing        ?      NaN
# 15       shweta     NaN               80       23       70  missing      NaN
# 16     siddhart     NaN              NaN       23      NaN      NaN       78
# 17       aditya     NaN              NaN       22  missing       80       90
# 18    pratiksha     NaN              NaN       21      NaN      NaN       70

# %%
df['Python'].dtype
# Out:
# dtype('float64')

# %%
df['Machine Learning']=pd.to_numeric(df['Machine Learning'],errors='coerce')

# %%
df
# Out:
#            Name  Python  Machine Learning      Age       AI      NLP       Cv
# 0         rishi    90.0               NaN       23       90        ?       23
# 1   rohit_madke     NaN              89.0      NaN  missing       89      NaN
# 2         sahil    78.0              78.0        ?       78       78        ?
# 3        rutuja     NaN               NaN  missing      NaN      NaN  missing
# 4       kasturi     NaN               NaN       21  missing      NaN       21
# 5        sanjil    65.0              56.0       22       65       56       22
# 6       swapnil    45.0              67.0        ?       45       67        ?
# 7         rajat    80.0              45.0       24       80       45       24
# 8       nishant    70.0              67.0  missing       70       67  missing
# 9      ramachal     NaN               NaN       22      NaN      NaN       22
# 10        javed     NaN               NaN       22        ?        ?       80
# 11        yuraj     NaN               NaN       20       80  missing       90
# 12      siddesh     NaN               NaN       23      NaN      NaN       80
# 13      prabhat     NaN               NaN       23       80       78  missing
# 14    rohit_sir     NaN               NaN       23  missing        ?      NaN
# 15       shweta     NaN              80.0       23       70  missing      NaN
# 16     siddhart     NaN               NaN       23      NaN      NaN       78
# 17       aditya     NaN               NaN       22  missing       80       90
# 18    pratiksha     NaN               NaN       21      NaN      NaN       70

# %%
df['Machine Learning'].dtype
# Out:
# dtype('float64')

# %%
df['Age']=pd.to_numeric(df.Age,errors='coerce')

# %%
df
# Out:
#            Name  Python  Machine Learning   Age       AI      NLP       Cv
# 0         rishi    90.0               NaN  23.0       90        ?       23
# 1   rohit_madke     NaN              89.0   NaN  missing       89      NaN
# 2         sahil    78.0              78.0   NaN       78       78        ?
# 3        rutuja     NaN               NaN   NaN      NaN      NaN  missing
# 4       kasturi     NaN               NaN  21.0  missing      NaN       21
# 5        sanjil    65.0              56.0  22.0       65       56       22
# 6       swapnil    45.0              67.0   NaN       45       67        ?
# 7         rajat    80.0              45.0  24.0       80       45       24
# 8       nishant    70.0              67.0   NaN       70       67  missing
# 9      ramachal     NaN               NaN  22.0      NaN      NaN       22
# 10        javed     NaN               NaN  22.0        ?        ?       80
# 11        yuraj     NaN               NaN  20.0       80  missing       90
# 12      siddesh     NaN               NaN  23.0      NaN      NaN       80
# 13      prabhat     NaN               NaN  23.0       80       78  missing
# 14    rohit_sir     NaN               NaN  23.0  missing        ?      NaN
# 15       shweta     NaN              80.0  23.0       70  missing      NaN
# 16     siddhart     NaN               NaN  23.0      NaN      NaN       78
# 17       aditya     NaN               NaN  22.0  missing       80       90
# 18    pratiksha     NaN               NaN  21.0      NaN      NaN       70

# %%
df.Age.dtype
# Out:
# dtype('float64')

# %%
df['AI']=pd.to_numeric(df.AI,errors='coerce')

# %%
df
# Out:
#            Name  Python  Machine Learning   Age    AI      NLP       Cv
# 0         rishi    90.0               NaN  23.0  90.0        ?       23
# 1   rohit_madke     NaN              89.0   NaN   NaN       89      NaN
# 2         sahil    78.0              78.0   NaN  78.0       78        ?
# 3        rutuja     NaN               NaN   NaN   NaN      NaN  missing
# 4       kasturi     NaN               NaN  21.0   NaN      NaN       21
# 5        sanjil    65.0              56.0  22.0  65.0       56       22
# 6       swapnil    45.0              67.0   NaN  45.0       67        ?
# 7         rajat    80.0              45.0  24.0  80.0       45       24
# 8       nishant    70.0              67.0   NaN  70.0       67  missing
# 9      ramachal     NaN               NaN  22.0   NaN      NaN       22
# 10        javed     NaN               NaN  22.0   NaN        ?       80
# 11        yuraj     NaN               NaN  20.0  80.0  missing       90
# 12      siddesh     NaN               NaN  23.0   NaN      NaN       80
# 13      prabhat     NaN               NaN  23.0  80.0       78  missing
# 14    rohit_sir     NaN               NaN  23.0   NaN        ?      NaN
# 15       shweta     NaN              80.0  23.0  70.0  missing      NaN
# 16     siddhart     NaN               NaN  23.0   NaN      NaN       78
# 17       aditya     NaN               NaN  22.0   NaN       80       90
# 18    pratiksha     NaN               NaN  21.0   NaN      NaN       70

# %%
df.AI.dtype
# Out:
# dtype('float64')

# %%
df['NLP']=pd.to_numeric(df.NLP,errors='coerce')

# %%
df
# Out:
#            Name  Python  Machine Learning   Age    AI   NLP       Cv
# 0         rishi    90.0               NaN  23.0  90.0   NaN       23
# 1   rohit_madke     NaN              89.0   NaN   NaN  89.0      NaN
# 2         sahil    78.0              78.0   NaN  78.0  78.0        ?
# 3        rutuja     NaN               NaN   NaN   NaN   NaN  missing
# 4       kasturi     NaN               NaN  21.0   NaN   NaN       21
# 5        sanjil    65.0              56.0  22.0  65.0  56.0       22
# 6       swapnil    45.0              67.0   NaN  45.0  67.0        ?
# 7         rajat    80.0              45.0  24.0  80.0  45.0       24
# 8       nishant    70.0              67.0   NaN  70.0  67.0  missing
# 9      ramachal     NaN               NaN  22.0   NaN   NaN       22
# 10        javed     NaN               NaN  22.0   NaN   NaN       80
# 11        yuraj     NaN               NaN  20.0  80.0   NaN       90
# 12      siddesh     NaN               NaN  23.0   NaN   NaN       80
# 13      prabhat     NaN               NaN  23.0  80.0  78.0  missing
# 14    rohit_sir     NaN               NaN  23.0   NaN   NaN      NaN
# 15       shweta     NaN              80.0  23.0  70.0   NaN      NaN
# 16     siddhart     NaN               NaN  23.0   NaN   NaN       78
# 17       aditya     NaN               NaN  22.0   NaN  80.0       90
# 18    pratiksha     NaN               NaN  21.0   NaN   NaN       70

# %%
df.NLP.dtype
# Out:
# dtype('float64')

# %%
df['Cv']=pd.to_numeric(df.Cv,errors='coerce')

# %%
df
# Out:
#            Name  Python  Machine Learning   Age    AI   NLP    Cv
# 0         rishi    90.0               NaN  23.0  90.0   NaN  23.0
# 1   rohit_madke     NaN              89.0   NaN   NaN  89.0   NaN
# 2         sahil    78.0              78.0   NaN  78.0  78.0   NaN
# 3        rutuja     NaN               NaN   NaN   NaN   NaN   NaN
# 4       kasturi     NaN               NaN  21.0   NaN   NaN  21.0
# 5        sanjil    65.0              56.0  22.0  65.0  56.0  22.0
# 6       swapnil    45.0              67.0   NaN  45.0  67.0   NaN
# 7         rajat    80.0              45.0  24.0  80.0  45.0  24.0
# 8       nishant    70.0              67.0   NaN  70.0  67.0   NaN
# 9      ramachal     NaN               NaN  22.0   NaN   NaN  22.0
# 10        javed     NaN               NaN  22.0   NaN   NaN  80.0
# 11        yuraj     NaN               NaN  20.0  80.0   NaN  90.0
# 12      siddesh     NaN               NaN  23.0   NaN   NaN  80.0
# 13      prabhat     NaN               NaN  23.0  80.0  78.0   NaN
# 14    rohit_sir     NaN               NaN  23.0   NaN   NaN   NaN
# 15       shweta     NaN              80.0  23.0  70.0   NaN   NaN
# 16     siddhart     NaN               NaN  23.0   NaN   NaN  78.0
# 17       aditya     NaN               NaN  22.0   NaN  80.0  90.0
# 18    pratiksha     NaN               NaN  21.0   NaN   NaN  70.0

# %%
df.Cv.dtype
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['Name', 'Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv'], dtype='object')

# %%
list1 = list(df.columns)

# %%
list1
# Out:
# ['Name', 'Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv']

# %%
list1 = list1[1:]

# %%
list1
# Out:
# ['Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv']

# %%
for i in list1:
    df[i].fillna(round(df[i].mean(),2),inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            19 non-null     float64
#  2   Machine Learning  19 non-null     float64
#  3   Age               19 non-null     float64
#  4   AI                19 non-null     float64
#  5   NLP               19 non-null     float64
#  6   Cv                19 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.2+ KB
