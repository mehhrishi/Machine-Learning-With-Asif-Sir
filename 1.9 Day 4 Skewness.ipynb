# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("cars (1).csv")
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
df["normalized-losses"].replace("?",np.nan,inplace=True)
df["horsepower"].replace("?",np.nan,inplace=True)

# %%
df["normalized-losses"]=df["normalized-losses"].astype("float")
df["horsepower"]=df["horsepower"].astype("float")

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="mean")

# %%
df[["normalized-losses","horsepower"]]=si.fit_transform(df[["normalized-losses","horsepower"]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    float64
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 24.1+ KB

# %%
sns.boxplot(data=df,x="price")
# Out:
# <AxesSubplot:xlabel='price'>

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=df,x="price",y="make")
plt.grid()

# %%
df[(df.make=="dodge") & (df.price>10000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 29          3              145.0  dodge       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 29           front   66.3    50.2         ohc          156       145.0
#
#     city-mpg  highway-mpg  price
# 29        19           24  12964

# %%
df.drop(29,axis=0,inplace=True)

# %%
df[(df.make=="honda") & (df.price>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0               85.0  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 41           front   65.2    54.1         ohc          110       101.0
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
df.drop(41,axis=0,inplace=True)

# %%
df[(df.make=="isuzu") & (df.price>20000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0              122.0  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90        70.0
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
df.drop(45,axis=0,inplace=True)

# %%
df[(df.make=="mitsubishi") & (df.price>14000)]
# Out:
#     symboling  normalized-losses        make fuel-type body-style  \
# 83          3              122.0  mitsubishi       gas  hatchback
# 84          3              122.0  mitsubishi       gas  hatchback
#
#    drive-wheels engine-location  width  height engine-type  engine-size  \
# 83          fwd           front   66.3    50.2         ohc          156
# 84          fwd           front   66.3    50.2         ohc          156
#
#     horsepower  city-mpg  highway-mpg  price
# 83       145.0        19           24  14869
# 84       145.0        19           24  14489

# %%
df.drop([83,84],axis=0,inplace=True)

# %%
df[(df.make=="plymouth") & (df.price>10000)]
# Out:
#      symboling  normalized-losses      make fuel-type body-style drive-wheels  \
# 124          3              122.0  plymouth       gas  hatchback          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 124           front   66.3    50.2         ohc          156       145.0
#
#      city-mpg  highway-mpg  price
# 124        19           24  12764

# %%
df.drop(124,axis=0,inplace=True)

# %%
df[(df.make=="toyota") & (df.price>15000)]
# Out:
#      symboling  normalized-losses    make fuel-type   body-style drive-wheels  \
# 172          2              134.0  toyota       gas  convertible          rwd
# 178          3              197.0  toyota       gas    hatchback          rwd
# 179          3              197.0  toyota       gas    hatchback          rwd
# 180         -1               90.0  toyota       gas        sedan          rwd
# 181         -1              122.0  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 172           front   65.6    53.0         ohc          146       116.0
# 178           front   67.7    52.0        dohc          171       161.0
# 179           front   67.7    52.0        dohc          171       161.0
# 180           front   66.5    54.1        dohc          171       156.0
# 181           front   66.5    54.1        dohc          161       156.0
#
#      city-mpg  highway-mpg  price
# 172        24           30  17669
# 178        20           24  16558
# 179        19           24  15998
# 180        20           24  15690
# 181        19           24  15750

# %%
df.drop([172,178,179,180,181],axis=0,inplace=True)

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=df,x="price",y="make")
plt.grid()

# %%
colname=df.select_dtypes(["int64","float64"]).columns

# %%
colname
# Out:
# Index(['symboling', 'normalized-losses', 'width', 'height', 'engine-size',
#        'horsepower', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
df[colname]
# Out:
#      symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0            3              122.0   64.1    48.8          130       111.0
# 1            3              122.0   64.1    48.8          130       111.0
# 2            1              122.0   65.5    52.4          152       154.0
# 3            2              164.0   66.2    54.3          109       102.0
# 4            2              164.0   66.4    54.3          136       115.0
# ..         ...                ...    ...     ...          ...         ...
# 200         -1               95.0   68.9    55.5          141       114.0
# 201         -1               95.0   68.8    55.5          141       160.0
# 202         -1               95.0   68.9    55.5          173       134.0
# 203         -1               95.0   68.9    55.5          145       106.0
# 204         -1               95.0   68.9    55.5          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [194 rows x 9 columns]

# %%
from scipy.stats import skew

# %%
skew(df["normalized-losses"])
# Out:
# 0.848205953606264

# %%
for col in df[colname]:
    print(col)
    print(skew(df[col]))
    
    sns.distplot(df[col])
    plt.show()
# Out:
# symboling
# 0.21386866184357742
# normalized-losses
# 0.848205953606264
# width
# 0.9140400320504322
# height
# 0.013839962443639326
# engine-size
# 2.0541257626466156
# horsepower
# 1.5556576549504106
# city-mpg
# 0.5999073033714895
# highway-mpg
# 0.4760310091695327
# price
# 1.8166794702973463

# %%
df.corr()
# Out:
#                    symboling  normalized-losses     width    height  \
# symboling           1.000000           0.447922 -0.272388 -0.521495
# normalized-losses   0.447922           1.000000  0.066622 -0.368540
# width              -0.272388           0.066622  1.000000  0.296011
# height             -0.521495          -0.368540  0.296011  1.000000
# engine-size        -0.153671           0.090258  0.735112  0.096041
# horsepower          0.027074           0.183385  0.643906 -0.078245
# city-mpg            0.007189          -0.212276 -0.641401 -0.078815
# highway-mpg         0.084238          -0.168904 -0.677911 -0.142926
# price              -0.095905           0.129973  0.730503  0.147010
#
#                    engine-size  horsepower  city-mpg  highway-mpg     price
# symboling            -0.153671    0.027074  0.007189     0.084238 -0.095905
# normalized-losses     0.090258    0.183385 -0.212276    -0.168904  0.129973
# width                 0.735112    0.643906 -0.641401    -0.677911  0.730503
# height                0.096041   -0.078245 -0.078815    -0.142926  0.147010
# engine-size           1.000000    0.803956 -0.642711    -0.667078  0.869638
# horsepower            0.803956    1.000000 -0.797166    -0.761009  0.768921
# city-mpg             -0.642711   -0.797166  1.000000     0.970113 -0.680412
# highway-mpg          -0.667078   -0.761009  0.970113     1.000000 -0.704846
# price                 0.869638    0.768921 -0.680412    -0.704846  1.000000

# %%
np.log(-5)
# Out:
# nan

# %%
np.sqrt(-3)
# Out:
# nan

# %%
df1=df.corr().style.background_gradient()
df1
# Out:
# <style type="text/css">
# #T_01cde_row0_col0, #T_01cde_row1_col1, #T_01cde_row2_col2, #T_01cde_row3_col3, #T_01cde_row4_col4, #T_01cde_row5_col5, #T_01cde_row6_col6, #T_01cde_row7_col7, #T_01cde_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_01cde_row0_col1 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_01cde_row0_col2, #T_01cde_row4_col0 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_01cde_row0_col3, #T_01cde_row3_col0, #T_01cde_row3_col1, #T_01cde_row5_col6, #T_01cde_row5_col7, #T_01cde_row6_col5, #T_01cde_row7_col2, #T_01cde_row7_col4, #T_01cde_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_01cde_row0_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_01cde_row0_col5, #T_01cde_row3_col4 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_01cde_row0_col6 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_01cde_row0_col7 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_01cde_row0_col8 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_01cde_row1_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_01cde_row1_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_01cde_row1_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_01cde_row1_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_01cde_row1_col5 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_01cde_row1_col6 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_01cde_row1_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_01cde_row1_col8 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_01cde_row2_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_01cde_row2_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_01cde_row2_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_01cde_row2_col4, #T_01cde_row2_col8, #T_01cde_row4_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_01cde_row2_col5 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_01cde_row2_col6, #T_01cde_row4_col6 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_01cde_row2_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_01cde_row3_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_01cde_row3_col5, #T_01cde_row3_col6 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_01cde_row3_col7 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_01cde_row3_col8 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_01cde_row4_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_01cde_row4_col3, #T_01cde_row5_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_01cde_row4_col5 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_01cde_row4_col7 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_01cde_row4_col8 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_01cde_row5_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_01cde_row5_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_01cde_row5_col3, #T_01cde_row6_col3 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_01cde_row5_col4 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_01cde_row5_col8 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_01cde_row6_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_01cde_row6_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_01cde_row6_col2, #T_01cde_row7_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_01cde_row6_col4, #T_01cde_row6_col8 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_01cde_row6_col7, #T_01cde_row7_col6 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_01cde_row7_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_01cde_row7_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_01cde_row7_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_01cde_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_01cde_row8_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_01cde_row8_col2 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_01cde_row8_col3 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_01cde_row8_col4 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_01cde_row8_col5 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_01cde_row8_col6 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_01cde_row8_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_01cde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01cde_level0_col0" class="col_heading level0 col0" >symboling</th>
#       <th id="T_01cde_level0_col1" class="col_heading level0 col1" >normalized-losses</th>
#       <th id="T_01cde_level0_col2" class="col_heading level0 col2" >width</th>
#       <th id="T_01cde_level0_col3" class="col_heading level0 col3" >height</th>
#       <th id="T_01cde_level0_col4" class="col_heading level0 col4" >engine-size</th>
#       <th id="T_01cde_level0_col5" class="col_heading level0 col5" >horsepower</th>
#       <th id="T_01cde_level0_col6" class="col_heading level0 col6" >city-mpg</th>
#       <th id="T_01cde_level0_col7" class="col_heading level0 col7" >highway-mpg</th>
#       <th id="T_01cde_level0_col8" class="col_heading level0 col8" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01cde_level0_row0" class="row_heading level0 row0" >symboling</th>
#       <td id="T_01cde_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_01cde_row0_col1" class="data row0 col1" >0.447922</td>
#       <td id="T_01cde_row0_col2" class="data row0 col2" >-0.272388</td>
#       <td id="T_01cde_row0_col3" class="data row0 col3" >-0.521495</td>
#       <td id="T_01cde_row0_col4" class="data row0 col4" >-0.153671</td>
#       <td id="T_01cde_row0_col5" class="data row0 col5" >0.027074</td>
#       <td id="T_01cde_row0_col6" class="data row0 col6" >0.007189</td>
#       <td id="T_01cde_row0_col7" class="data row0 col7" >0.084238</td>
#       <td id="T_01cde_row0_col8" class="data row0 col8" >-0.095905</td>
#     </tr>
#     <tr>
#       <th id="T_01cde_level0_row1" class="row_heading level0 row1" >normalized-losses</th>
#       <td id="T_01cde_row1_col0" class="data row1 col0" >0.447922</td>
#       <td id="T_01cde_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_01cde_row1_col2" class="data row1 col2" >0.066622</td>
#       <td id="T_01cde_row1_col3" class="data row1 col3" >-0.368540</td>
#       <td id="T_01cde_row1_col4" class="data row1 col4" >0.090258</td>
#       <td id="T_01cde_row1_col5" class="data row1 col5" >0.183385</td>
#       <td id="T_01cde_row1_col6" class="data row1 col6" >-0.212276</td>
#       <td id="T_01cde_row1_col7" class="data row1 col7" >-0.168904</td>
#       <td id="T_01cde_row1_col8" class="data row1 col8" >0.129973</td>
#     </tr>
#     <tr>
#       <th id="T_01cde_level0_row2" class="row_heading level0 row2" >width</th>
#       <td id="T_01cde_row2_col0" class="data row2 col0" >-0.272388</td>
#       <td id="T_01cde_row2_col1" class="data row2 col1" >0.066622</td>
#       <td id="T_01cde_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_01cde_row2_col3" class="data row2 col3" >0.296011</td>
#       <td id="T_01cde_row2_col4" class="data row2 col4" >0.735112</td>
#       <td id="T_01cde_row2_col5" class="data row2 col5" >0.643906</td>
#       <td id="T_01cde_row2_col6" class="data row2 col6" >-0.641401</td>
#       <td id="T_01cde_row2_col7" class="data row2 col7" >-0.677911</td>
#       <td id="T_01cde_row2_col8" class="data row2 col8" >0.730503</td>
#     </tr>
#     <tr>
#       <th id="T_01cde_level0_row3" class="row_heading level0 row3" >height</th>
#       <td id="T_01cde_row3_col0" class="data row3 col0" >-0.521495</td>
#       <td id="T_01cde_row3_col1" class="data row3 col1" >-0.368540</td>
#       <td id="T_01cde_row3_col2" class="data row3 col2" >0.296011</td>
#       <td id="T_01cde_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_01cde_row3_col4" class="data row3 col4" >0.096041</td>
#       <td id="T_01cde_row3_col5" class="data row3 col5" >-0.078245</td>
#       <td id="T_01cde_row3_co

# %%
skew(df["normalized-losses"])
# Out:
# 0.848205953606264

# %%
df['normalized-losses']=np.log(df["normalized-losses"])
# df['normalized-losses']=np.sqrt(df["normalized-losses"])

# %%
skew(df["normalized-losses"])
# Out:
# 0.018468899462087518

# %%
sns.distplot(df['normalized-losses'])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='Density'>

# %%
for col in df[colname]:
    print(col)
    print(skew(df[col]))
    
    sns.distplot(df[col])
    plt.show()
# Out:
# symboling
# 0.21386866184357742
# normalized-losses
# 0.018468899462087518
# width
# 0.9140400320504322
# height
# 0.013839962443639326
# engine-size
# 2.0541257626466156
# horsepower
# 1.5556576549504106
# city-mpg
# 0.5999073033714895
# highway-mpg
# 0.4760310091695327
# price
# 1.8166794702973463

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_e1917_row0_col0, #T_e1917_row1_col1, #T_e1917_row2_col2, #T_e1917_row3_col3, #T_e1917_row4_col4, #T_e1917_row5_col5, #T_e1917_row6_col6, #T_e1917_row7_col7, #T_e1917_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e1917_row0_col1 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_e1917_row0_col2, #T_e1917_row4_col0 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_e1917_row0_col3, #T_e1917_row3_col0, #T_e1917_row3_col1, #T_e1917_row5_col6, #T_e1917_row5_col7, #T_e1917_row6_col5, #T_e1917_row7_col2, #T_e1917_row7_col4, #T_e1917_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e1917_row0_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e1917_row0_col5, #T_e1917_row3_col4 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_e1917_row0_col6 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_e1917_row0_col7 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_e1917_row0_col8 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_e1917_row1_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_e1917_row1_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_e1917_row1_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e1917_row1_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_e1917_row1_col5 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_e1917_row1_col6 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_e1917_row1_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_e1917_row1_col8 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_e1917_row2_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_e1917_row2_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_e1917_row2_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_e1917_row2_col4, #T_e1917_row2_col8, #T_e1917_row4_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_e1917_row2_col5 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_e1917_row2_col6, #T_e1917_row4_col6 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_e1917_row2_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e1917_row3_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_e1917_row3_col5, #T_e1917_row3_col6 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_e1917_row3_col7 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_e1917_row3_col8 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_e1917_row4_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_e1917_row4_col3, #T_e1917_row5_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_e1917_row4_col5 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_e1917_row4_col7 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e1917_row4_col8 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_e1917_row5_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_e1917_row5_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_e1917_row5_col3, #T_e1917_row6_col3 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_e1917_row5_col4 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_e1917_row5_col8 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_e1917_row6_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_e1917_row6_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_e1917_row6_col2, #T_e1917_row7_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_e1917_row6_col4, #T_e1917_row6_col8 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e1917_row6_col7, #T_e1917_row7_col6 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_e1917_row7_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_e1917_row7_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_e1917_row7_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_e1917_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_e1917_row8_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_e1917_row8_col2 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_e1917_row8_col3 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_e1917_row8_col4 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_e1917_row8_col5 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_e1917_row8_col6 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_e1917_row8_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_e1917">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1917_level0_col0" class="col_heading level0 col0" >symboling</th>
#       <th id="T_e1917_level0_col1" class="col_heading level0 col1" >normalized-losses</th>
#       <th id="T_e1917_level0_col2" class="col_heading level0 col2" >width</th>
#       <th id="T_e1917_level0_col3" class="col_heading level0 col3" >height</th>
#       <th id="T_e1917_level0_col4" class="col_heading level0 col4" >engine-size</th>
#       <th id="T_e1917_level0_col5" class="col_heading level0 col5" >horsepower</th>
#       <th id="T_e1917_level0_col6" class="col_heading level0 col6" >city-mpg</th>
#       <th id="T_e1917_level0_col7" class="col_heading level0 col7" >highway-mpg</th>
#       <th id="T_e1917_level0_col8" class="col_heading level0 col8" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1917_level0_row0" class="row_heading level0 row0" >symboling</th>
#       <td id="T_e1917_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e1917_row0_col1" class="data row0 col1" >0.447922</td>
#       <td id="T_e1917_row0_col2" class="data row0 col2" >-0.272388</td>
#       <td id="T_e1917_row0_col3" class="data row0 col3" >-0.521495</td>
#       <td id="T_e1917_row0_col4" class="data row0 col4" >-0.153671</td>
#       <td id="T_e1917_row0_col5" class="data row0 col5" >0.027074</td>
#       <td id="T_e1917_row0_col6" class="data row0 col6" >0.007189</td>
#       <td id="T_e1917_row0_col7" class="data row0 col7" >0.084238</td>
#       <td id="T_e1917_row0_col8" class="data row0 col8" >-0.095905</td>
#     </tr>
#     <tr>
#       <th id="T_e1917_level0_row1" class="row_heading level0 row1" >normalized-losses</th>
#       <td id="T_e1917_row1_col0" class="data row1 col0" >0.447922</td>
#       <td id="T_e1917_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e1917_row1_col2" class="data row1 col2" >0.066622</td>
#       <td id="T_e1917_row1_col3" class="data row1 col3" >-0.368540</td>
#       <td id="T_e1917_row1_col4" class="data row1 col4" >0.090258</td>
#       <td id="T_e1917_row1_col5" class="data row1 col5" >0.183385</td>
#       <td id="T_e1917_row1_col6" class="data row1 col6" >-0.212276</td>
#       <td id="T_e1917_row1_col7" class="data row1 col7" >-0.168904</td>
#       <td id="T_e1917_row1_col8" class="data row1 col8" >0.129973</td>
#     </tr>
#     <tr>
#       <th id="T_e1917_level0_row2" class="row_heading level0 row2" >width</th>
#       <td id="T_e1917_row2_col0" class="data row2 col0" >-0.272388</td>
#       <td id="T_e1917_row2_col1" class="data row2 col1" >0.066622</td>
#       <td id="T_e1917_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e1917_row2_col3" class="data row2 col3" >0.296011</td>
#       <td id="T_e1917_row2_col4" class="data row2 col4" >0.735112</td>
#       <td id="T_e1917_row2_col5" class="data row2 col5" >0.643906</td>
#       <td id="T_e1917_row2_col6" class="data row2 col6" >-0.641401</td>
#       <td id="T_e1917_row2_col7" class="data row2 col7" >-0.677911</td>
#       <td id="T_e1917_row2_col8" class="data row2 col8" >0.730503</td>
#     </tr>
#     <tr>
#       <th id="T_e1917_level0_row3" class="row_heading level0 row3" >height</th>
#       <td id="T_e1917_row3_col0" class="data row3 col0" >-0.521495</td>
#       <td id="T_e1917_row3_col1" class="data row3 col1" >-0.368540</td>
#       <td id="T_e1917_row3_col2" class="data row3 col2" >0.296011</td>
#       <td id="T_e1917_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e1917_row3_col4" class="data row3 col4" >0.096041</td>
#       <td id="T_e1917_row3_col5" class="data row3 col5" >-0.078245</td>
#       <td id="T_e1917_row3_co

# %%
df.head(3)
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# 1       111.0        21           27  16500
# 2       154.0        19           26  16500

# %%
skew(df['symboling'])
# Out:
# 0.21386866184357742
