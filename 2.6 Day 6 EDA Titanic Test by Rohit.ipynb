# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Order to handle missing values
#     First drop all unnecessary colummns
#     Convert all missing values into NaN values
#     Fill The Mean Values
#     Drop all unnecessary rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.drop(['Cabin','PassengerId','Ticket'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch     Fare Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch     Fare Embarked
# ...

# %%
sns.boxplot(data=df,x='Pclass',y='Fare')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
def convert(col,other):
    f_df=pd.DataFrame(columns=df.columns)
    for i in df[other].unique():
        temp_df=df[df[other]==i]
        q1=temp_df[col].quantile(0.25)
        q3=temp_df[col].quantile(0.75)
        iqr=q3-q1
        min_val=q1-(1.5*iqr)
        max_val=q3+(1.5*iqr)
        temp_df=temp_df[(temp_df[col]>=min_val) & (temp_df[col]<=max_val)]
        f_df=pd.merge(f_df,temp_df,how='outer')
        
    return (f_df)

# %%
new_df=convert('Fare','Pclass')
new_df
plt.figure(figsize=(10,8))
sns.boxplot(x=new_df['Pclass'],y=new_df['Fare'],data=new_df)
plt.grid()
plt.show()

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.335549 -0.074673 -0.034040  0.083151  0.255290
# Pclass   -0.335549  1.000000 -0.327954  0.081656  0.016824 -0.548193
# Age      -0.074673 -0.327954  1.000000 -0.231875 -0.178232  0.088604
# SibSp    -0.034040  0.081656 -0.231875  1.000000  0.414542  0.160887
# Parch     0.083151  0.016824 -0.178232  0.414542  1.000000  0.217532
# Fare      0.255290 -0.548193  0.088604  0.160887  0.217532  1.000000

# %%
from scipy.stats import skew

# %%
colname=df.select_dtypes(["int64","float64"])

# %%
skew(df['Pclass'])
# Out:
# -0.635922455085956

# %%
colname
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare
# 0           0       3  22.000000      1      0   7.2500
# 1           1       1  38.000000      1      0  71.2833
# 2           1       3  26.000000      0      0   7.9250
# 3           1       1  35.000000      1      0  53.1000
# 4           0       3  35.000000      0      0   8.0500
# ..        ...     ...        ...    ...    ...      ...
# 886         0       2  27.000000      0      0  13.0000
# 887         1       1  19.000000      0      0  30.0000
# 888         0       3  29.699118      1      2  23.4500
# 889         1       1  26.000000      0      0  30.0000
# 890         0       3  32.000000      0      0   7.7500
#
# [889 rows x 6 columns]

# %%
for col in colname:
    print(col)
    print(skew(df[col]))
    
    sns.distplot(colname)
    plt.show()
# Out:
# Survived
# 0.4837496405947267
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Pclass
# -0.635922455085956
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Age
# 0.4309914863386608
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch     Fare Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch     Fare Embarked
# ...

# %%
#peron with highest age survived
df[df.Age==df.Age.max()]
# Out:
#      Survived  Pclass                                  Name   Sex   Age  \
# 630         1       1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
#
#      SibSp  Parch  Fare Embarked
# 630      0      0  30.0        S

# %%
#child with min agre survived
df[df.Age==df.Age.min()]
# Out:
#      Survived  Pclass                             Name   Sex   Age  SibSp  \
# 803         1       3  Thomas, Master. Assad Alexander  male  0.42      0
#
#      Parch    Fare Embarked
# 803      1  8.5167        C

# %%
new_df=df[df.Survived==1]

# %%
plt.figure(figsize=(10,6))
age_mean=new_df.Age.mean()
age_median=new_df.Age.median()
plt.axvline(age_mean,color='red',label='Age Mean')
plt.axvline(age_median,color='yellow',label='Age Median')
sns.distplot(new_df['Age'],bins=5)
plt.grid()
# Out:
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Fare'],bins=10)
# Out:
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
new_df
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# ..        ...     ...                                                ...
# 875         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch     Fare Embarked
# ...

# %%
sns.countplot('Survived',data=df)
# Out:
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot('Sex',hue='Survived',data=df)
# Out:
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch     Fare Embarked
# ...

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sns.countplot('Embarked',hue='Survived',data=df)
# Out:
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch     Fare Embarked
# ...

# %%
sns.countplot('Pclass',hue='Survived',data=df)
plt.show()
# Out:
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for col in colname:
    print(col)
    print(skew(df[col]))
    
    sns.distplot(colname)
    plt.show()
# Out:
# Survived
# 0.4837496405947267
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Pclass
# -0.635922455085956
# C:\Users\Rohit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Age
# 0.4309914863386608
# ...

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.335549 -0.074673 -0.034040  0.083151  0.255290
# Pclass   -0.335549  1.000000 -0.327954  0.081656  0.016824 -0.548193
# Age      -0.074673 -0.327954  1.000000 -0.231875 -0.178232  0.088604
# SibSp    -0.034040  0.081656 -0.231875  1.000000  0.414542  0.160887
# Parch     0.083151  0.016824 -0.178232  0.414542  1.000000  0.217532
# Fare      0.255290 -0.548193  0.088604  0.160887  0.217532  1.000000

# %%
df['Parch']=np.sqrt(df['Parch'])
skew(df['Parch'])
# Out:
# 1.5237213630517692

# %%
df['Fare']=np.sqrt(df['Fare'])
skew(df['Fare'])
# Out:
# 2.0961167314359144

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.335549 -0.074673 -0.034040  0.123454  0.309778
# Pclass   -0.335549  1.000000 -0.327954  0.081656 -0.008720 -0.659204
# Age      -0.074673 -0.327954  1.000000 -0.231875 -0.236318  0.104474
# SibSp    -0.034040  0.081656 -0.231875  1.000000  0.465089  0.259831
# Parch     0.123454 -0.008720 -0.236318  0.465089  1.000000  0.322840
# Fare      0.309778 -0.659204  0.104474  0.259831  0.322840  1.000000

# %%
#can we use log and sqrt at the same time
#what if skewness doesnt approaches zero even after removing skewness and corelation as well

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp     Parch      Fare Embarked
# ...

# %%
def plot(var):
    plt.figure(figsize=(10,6))
    sns.histplot(df[var],color='orange')
    plt.axvline(df[var].mean(),color='red',label='Mean')
    plt.axvline(df[var].median(),color='red',label='Median')

# %%
l1=['Age','Fare','SibSp']
for i in l1:
    plot(i)

# %%
list1 = ["SibSp", "Parch", "Age", "Fare", "Survived"]
sns.heatmap(df[list1].corr(), annot = True, fmt = ".2f")
plt.show()
