# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Here the Target column is "Survived"

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# dropping the rows of "Embarked"
df.dropna(subset='Embarked',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
# lets Drop the Cabin Column
df.drop(columns="Cabin",axis=1,inplace=True)

# %%
df.drop(columns="PassengerId",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    int64
#  1   Pclass    889 non-null    int64
#  2   Name      889 non-null    object
#  3   Sex       889 non-null    object
#  4   Age       712 non-null    float64
#  5   SibSp     889 non-null    int64
#  6   Parch     889 non-null    int64
#  7   Ticket    889 non-null    object
#  8   Fare      889 non-null    float64
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 76.4+ KB

# %%
df['Age'].mean()
# Out:
# 29.64209269662921

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
# df["Age"] = df.fillna(df["Age"].mean())
# df

# %%
# let apply mean on Nan for Age Column  
df.fillna(int(df['Age'].mean()),inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    312
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts().sum()
# Out:
# 889

# %%
plt.grid()
sns.countplot(data = df,x = "Sex" )
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500        S
# 1  female  38.0      1      0          PC 17599  71.2833        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  female  35.0      1      0            113803  53.1000        S
# 4    male  35.0      0      0            373450   8.0500        S

# %%
# 
sns.countplot(data = df,x = "Sex",hue="Survived" )
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(data=df,x= "Fare",y = "Sex")
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Sex'>

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df.loc[:,['Name',"Pclass","Fare"]].min()
# Out:
# Name      Abbing, Mr. Anthony
# Pclass                      1
# Fare                      0.0
# dtype: object

# %%
df.loc[:,['Name',"Pclass","Fare"]].max()
# Out:
# Name      van Melkebeke, Mr. Philemon
# Pclass                              3
# Fare                         512.3292
# dtype: object

# %%
# let remove the Outlier 
# x = "Fare"
# y = "Pclass"
sns.boxplot(data=df,x = "Pclass",y = "Fare")
plt.ylim(0,600)
plt.grid()
plt.show()

# %%
df[(df['Pclass']==2)].describe()
# Out:
#          Survived  Pclass         Age       SibSp       Parch        Fare
# count  184.000000   184.0  184.000000  184.000000  184.000000  184.000000
# mean     0.472826     2.0   29.825163    0.402174    0.380435   20.662183
# std      0.500623     0.0   13.575362    0.601633    0.690963   13.417399
# min      0.000000     2.0    0.670000    0.000000    0.000000    0.000000
# 25%      0.000000     2.0   23.000000    0.000000    0.000000   13.000000
# 50%      0.000000     2.0   29.000000    0.000000    0.000000   14.250000
# 75%      1.000000     2.0   36.000000    1.000000    1.000000   26.000000
# max      1.000000     2.0   70.000000    3.000000    3.000000   73.500000

# %%
# IQR

# %%
q1 = df[(df['Pclass']==2)]['Fare'].quantile(0.25)
q1
# Out:
# 13.0

# %%
q2 = df[(df['Pclass']==2)]['Fare'].quantile(0.50)
q2
# Out:
# 14.25

# %%
q3 = df[(df['Pclass']==2)]['Fare'].quantile(0.75)
q3
# Out:
# 26.0

# %%
iqr = q3 - q1
iqr
# Out:
# 13.0

# %%
max_val = q3+(1.5*iqr)
max_val
# Out:
# 45.5

# %%
min_val = q1-(1.5*iqr)
min_val
# Out:
# -6.5

# %%
df[(df['Fare']==13)]
# Out:
#      Survived  Pclass                                        Name     Sex  \
# 17          1       2                Williams, Mr. Charles Eugene    male
# 21          1       2                       Beesley, Mr. Lawrence    male
# 123         1       2                         Webber, Miss. Susan  female
# 134         0       2              Sobey, Mr. Samuel James Hayden    male
# 149         0       2           Byles, Rev. Thomas Roussel Davids    male
# 178         0       2                          Hale, Mr. Reginald    male
# 190         1       2                         Pinsky, Mrs. (Rosa)  female
# 191         0       2                       Carbines, Mr. William    male
# 199         0       2      Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 213         0       2                 Givard, Mr. Hans Kristensen    male
# 221         0       2                        Bracken, Mr. James H    male
# 228         0       2                   Fahlstrom, Mr. Arne Jonas    male
# ...

# %%
df.groupby("Fare").get_group(-6.5).loc[:,['Name']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [191], line 1
# ----> 1 df.groupby("Fare").get_group(-6.5).loc[:,['Name']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:747, in BaseGroupBy.get_group(self, name, obj)
#     745 inds = self._get_index(name)
#     746 if not len(inds):
# --> 747     raise KeyError(name)
#     749 return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: -6.5

# %%
df[(df['Pclass']==2)].max()
# Out:
# Survived                            1
# Pclass                              2
# Name        del Carlo, Mr. Sebastiano
# Sex                              male
# Age                              70.0
# SibSp                               3
# Parch                               3
# Ticket                      W/C 14208
# Fare                             73.5
# Embarked                            S
# dtype: object

# %%
# let remove the Outlier 
# x = "Fare"
# y = "Pclass"
sns.boxplot(data=df,x = "Pclass",y = "Fare")
plt.ylim(0,600)
plt.grid()
plt.show()

# %%
df[(df.Pclass==1) & (df.Fare>200)]
# Out:
#      Survived  Pclass                                               Name  \
# 27          0       1                     Fortune, Mr. Charles Alexander
# 88          1       1                         Fortune, Miss. Mabel Helen
# 118         0       1                           Baxter, Mr. Quigg Edmond
# 258         1       1                                   Ward, Miss. Anna
# 299         1       1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 311         1       1                         Ryerson, Miss. Emily Borie
# 341         1       1                     Fortune, Miss. Alice Elizabeth
# 377         0       1                          Widener, Mr. Harry Elkins
# 380         1       1                              Bidois, Miss. Rosalie
# 438         0       1                                  Fortune, Mr. Mark
# 527         0       1                                 Farthing, Mr. John
# 557         0       1                                Robbins, Mr. Victor
# ...

# %%
df[(df.Pclass==1) & (df.Fare>200)].index
# Out:
# Int64Index([ 27,  88, 118, 258, 299, 311, 341, 377, 380, 438, 527, 557, 679,
#             689, 700, 716, 730, 737, 742, 779],
#            dtype='int64')

# %%
df.drop(index=[27,  88, 118, 258, 299, 311, 341, 377, 380, 438, 527, 557, 679,
            689, 700, 716, 730, 737, 742, 779],inplace=True)

# %%
sns.boxplot(data=df,x = "Pclass",y = "Fare")
plt.ylim(0,600)
plt.grid()
plt.show()

# %%
df[(df.Pclass==2) & (df.Fare>45.4)]
# Out:
#      Survived  Pclass                              Name     Sex   Age  SibSp  \
# 72          0       2              Hood, Mr. Ambrose Jr    male  21.0      0
# 120         0       2       Hickman, Mr. Stanley George    male  21.0      2
# 385         0       2         Davies, Mr. Charles Henry    male  18.0      0
# 615         1       2               Herman, Miss. Alice  female  24.0      1
# 655         0       2         Hickman, Mr. Leonard Mark    male  24.0      2
# 665         0       2                Hickman, Mr. Lewis    male  32.0      2
# 754         1       2  Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
#
#      Parch        Ticket  Fare Embarked
# 72       0  S.O.C. 14879  73.5        S
# 120      0  S.O.C. 14879  73.5        S
# 385      0  S.O.C. 14879  73.5        S
# 615      2        220845  65.0        S
# 655      0  S.O.C. 14879  73.5        S
# 665      0  S.O.C. 14879  73.5        S
# 754      2        220845  65.0        S

# %%
df[(df.Pclass==2) & (df.Fare>45.4)].index
# Out:
# Int64Index([72, 120, 385, 615, 655, 665, 754], dtype='int64')

# %%
df.drop(index=[72, 120, 385, 615, 655, 665, 754],inplace=True)

# %%
sns.boxplot(data=df,x = "Pclass",y = "Fare")
plt.ylim(0,600)
plt.grid()
plt.show()

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                            McCarthy, Mr. Timothy J
# 11          1       1                           Bonnell, Miss. Elizabeth
# 23          1       1                       Sloper, Mr. William Thompson
# ..        ...     ...                                                ...
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Embarked
# ...

# %%
colname = df.select_dtypes(['int64','float64']).columns

# %%
colname
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
df[colname]
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3  29.0      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [862 rows x 6 columns]

# %%
# Lets find the skewness for the Column 
from scipy.stats import skew

# %%
skew(df['Survived'])
# Out:
# 0.512566396120414

# %%
for col in df[colname]:
    print(col)
    print(skew(df[col]))
    
    sns.distplot(df[col])
    plt.show()
# Out:
# Survived
# 0.512566396120414
# Pclass
# -0.7108457178289501
# Age
# 0.4490929832902517
# SibSp
# 3.7847232660451775
# Parch
# 2.8624902476338803
# Fare
# 2.3335363758221983

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.328130 -0.079212 -0.038049  0.074454  0.302229
# Pclass   -0.328130  1.000000 -0.342355  0.095196  0.050756 -0.652423
# Age      -0.079212 -0.342355  1.000000 -0.230793 -0.194003  0.129014
# SibSp    -0.038049  0.095196 -0.230793  1.000000  0.412409  0.245194
# Parch     0.074454  0.050756 -0.194003  0.412409  1.000000  0.234861
# Fare      0.302229 -0.652423  0.129014  0.245194  0.234861  1.000000

# %%
skew(df['Parch'])
# Out:
# 2.8624902476338803

# %%
# lets remove the skewness of this column bcause both its condition (Skew and Correlation)
# are False
df['Parch'] = np.sqrt(df['Parch'])

# %%
skew(df['Parch'])
# Out:
# 1.5890536735239789

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.328130 -0.079212 -0.038049  0.112601  0.302229
# Pclass   -0.328130  1.000000 -0.342355  0.095196  0.025492 -0.652423
# Age      -0.079212 -0.342355  1.000000 -0.230793 -0.250821  0.129014
# SibSp    -0.038049  0.095196 -0.230793  1.000000  0.466522  0.245194
# Parch     0.112601  0.025492 -0.250821  0.466522  1.000000  0.265008
# Fare      0.302229 -0.652423  0.129014  0.245194  0.265008  1.000000

# %%
skew(df['Fare'])
# Out:
# 2.3335363758221983

# %%
df['Fare'] = np.sqrt(df['Fare'])

# %%
skew(df['Fare'])
# Out:
# 1.295030576496642

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.328130 -0.079212 -0.038049  0.112601  0.324092
# Pclass   -0.328130  1.000000 -0.342355  0.095196  0.025492 -0.676843
# Age      -0.079212 -0.342355  1.000000 -0.230793 -0.250821  0.125888
# SibSp    -0.038049  0.095196 -0.230793  1.000000  0.466522  0.309446
# Parch     0.112601  0.025492 -0.250821  0.466522  1.000000  0.323829
# Fare      0.324092 -0.676843  0.125888  0.309446  0.323829  1.000000

# %%
df.Survived.reset_index().count()
# Out:
# index       862
# Survived    862
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [223], line 1
# ----> 1 df[(df.groupby('Survived'))]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5791, in Index._get_indexer_strict(self, key, axis_name)
#    5788     keyarr = com.asarray_tuplesafe(keyarr)
#    5790 if self._index_as_unique:
# -> 5791     indexer = self.get_indexer_for(keyarr)
#    5792     keyarr = self.reindex(keyarr)[0]
#    5793 else:
#
# ...
