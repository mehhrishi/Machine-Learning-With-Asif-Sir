# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("cars (1).csv")
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df["normalized-losses"].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
df["horsepower"].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 101     6
# 160     6
# 114     6
# 84      5
# 97      5
# 102     5
# 145     5
# 82      5
# 76      5
# 111     4
# 92      4
# 123     4
# 86      4
# 90      3
# 73      3
# 85      3
# 207     3
# 182     3
# 121     3
# 152     3
# 112     2
# 56      2
# 161     2
# 156     2
# 94      2
# 52      2
# ?       2
# 162     2
# 155     2
# 184     2
# 100     2
# 176     2
# 55      1
# 262     1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 135     1
# 200     1
# 64      1
# 120     1
# 72      1
# 154     1
# 288     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: horsepower, dtype: int64

# %%
#Step1:- Replace The ? with the NaN.

df["normalized-losses"].replace("?",np.nan,inplace=True)
df["horsepower"].replace("?",np.nan,inplace=True)


#Step2:- Change The DataTypes.

df["normalized-losses"]=df["normalized-losses"].astype("float")
df["horsepower"]=df["horsepower"].astype("float")

#Step3:- Get the Mean Value

nmean=df["normalized-losses"].mean()
hmean=df["horsepower"].mean()

#Step4:- Use Fillna Method

df["normalized-losses"].fillna(nmean,inplace=True)
df["horsepower"].fillna(hmean,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    float64
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# ...

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df,x = 'price')
plt.grid()
plt.show()

# %%
df[(df.make=='dodge') & (df.price>10000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 29          3              145.0  dodge       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 29           front   66.3    50.2         ohc          156       145.0
#
#     city-mpg  highway-mpg  price
# 29        19           24  12964

# %%
df.drop(index=29,axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = df,x = 'price',y = 'make')
plt.grid()
plt.show()

# %%
df[(df.make=='honda') & (df.price>11000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0               85.0  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 41           front   65.2    54.1         ohc          110       101.0
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
df.drop(index=41,axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = df,x = 'price',y = 'make')
plt.grid()
plt.show()

# %%
df[(df.make=='isuzu') & (df.price>20000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0              122.0  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90        70.0
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
df.drop(index=45,axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = df,x = 'price',y = 'make')
plt.grid()
plt.show()

# %%
df[(df.make=='mitsubishi') & (df.price>14000)]
# Out:
#     symboling  normalized-losses        make fuel-type body-style  \
# 83          3              122.0  mitsubishi       gas  hatchback
# 84          3              122.0  mitsubishi       gas  hatchback
#
#    drive-wheels engine-location  width  height engine-type  engine-size  \
# 83          fwd           front   66.3    50.2         ohc          156
# 84          fwd           front   66.3    50.2         ohc          156
#
#     horsepower  city-mpg  highway-mpg  price
# 83       145.0        19           24  14869
# 84       145.0        19           24  14489

# %%
df.drop(index=[83,84],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = df,x = 'price',y = 'make')
plt.grid()
plt.show()

# %%
df[(df.make=='plymouth') & (df.price>10000)]
# Out:
#      symboling  normalized-losses      make fuel-type body-style drive-wheels  \
# 124          3              122.0  plymouth       gas  hatchback          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 124           front   66.3    50.2         ohc          156       145.0
#
#      city-mpg  highway-mpg  price
# 124        19           24  12764

# %%
df.drop(index=124,axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = df,x = 'price',y = 'make')
plt.grid()
plt.show()

# %%
df[(df.make=='toyota') & (df.price>15000)]
# Out:
#      symboling  normalized-losses    make fuel-type   body-style drive-wheels  \
# 172          2              134.0  toyota       gas  convertible          rwd
# 178          3              197.0  toyota       gas    hatchback          rwd
# 179          3              197.0  toyota       gas    hatchback          rwd
# 180         -1               90.0  toyota       gas        sedan          rwd
# 181         -1              122.0  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 172           front   65.6    53.0         ohc          146       116.0
# 178           front   67.7    52.0        dohc          171       161.0
# 179           front   67.7    52.0        dohc          171       161.0
# 180           front   66.5    54.1        dohc          171       156.0
# 181           front   66.5    54.1        dohc          161       156.0
#
#      city-mpg  highway-mpg  price
# ...

# %%
df[(df.make=='toyota') & (df.price>15000)].index
# Out:
# Int64Index([172, 178, 179, 180, 181], dtype='int64')

# %%
df.drop(index=[172, 178, 179, 180, 181],axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = df,x = 'price',y = 'make')
plt.grid()
plt.show()

# %%
df['price'].describe()
# Out:
# count      199.000000
# mean     13168.854271
# std       7989.687787
# min       5118.000000
# 25%       7775.000000
# 50%      10198.000000
# 75%      16501.500000
# max      45400.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = df,x = 'price',y = 'engine-type')
plt.grid()
plt.show()

# %%
df[(df['engine-type']=='ohc') & (df.price>21000)]
# Out:
#      symboling  normalized-losses           make fuel-type body-style  \
# 8            1              158.0           audi       gas      sedan
# 13           0              188.0            bmw       gas      sedan
# 14           1              122.0            bmw       gas      sedan
# 15           0              122.0            bmw       gas      sedan
# 16           0              122.0            bmw       gas      sedan
# 17           0              122.0            bmw       gas      sedan
# 67          -1               93.0  mercedes-benz    diesel      sedan
# 68          -1               93.0  mercedes-benz    diesel      wagon
# 69           0               93.0  mercedes-benz    diesel    hardtop
# 70          -1               93.0  mercedes-benz    diesel      sedan
# 125          3              186.0        porsche       gas  hatchback
# 203         -1               95.0          volvo    diesel      sedan
# ...

# %%
df[(df['engine-type']=='ohc') & (df.price>21000)].index
# Out:
# Int64Index([8, 13, 14, 15, 16, 17, 67, 68, 69, 70, 125, 203, 204], dtype='int64')

# %%
df.drop(index=[8, 13, 14, 15, 16, 17, 67, 68, 69, 70, 125, 203, 204],
       axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = df,x = 'price',y = 'engine-type')
plt.grid()
plt.show()

# %%
df['engine-type'].value_counts()
# Out:
# ohc      128
# ohcf      15
# ohcv      13
# l         12
# dohc       8
# rotor      4
# dohcv      1
# Name: engine-type, dtype: int64
